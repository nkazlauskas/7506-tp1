# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
installs = pd.read_csv('installs.csv')
installs
# Out:
#                       created  application_id             ref_type  \
# 0     2019-03-13 01:43:33.445               0  1891515180541284343
# 1     2019-03-13 04:58:35.078               0  1891515180541284343
# 2     2019-03-13 04:20:57.666               0  1891515180541284343
# 3     2019-03-13 04:20:57.698               0  1891515180541284343
# 4     2019-03-10 22:24:56.684               0  1891515180541284343
# 5     2019-03-10 22:24:57.545               0  1891515180541284343
# 6     2019-03-11 03:47:22.802               0  1891515180541284343
# 7     2019-03-11 21:21:05.986               0  1891515180541284343
# 8     2019-03-11 21:21:05.855               0  1891515180541284343
# 9     2019-03-13 08:29:31.875               2  1891515180541284343
# 10    2019-03-13 04:30:00.812               2  1891515180541284343
# 11    2019-03-13 00:26:32.561               2  1891515180541284343
# 12    2019-03-13 11:36:30.025               2  1891515180541284343
# ...

# %%
installs.columns
# Out:
# Index(['created', 'application_id', 'ref_type', 'ref_hash', 'click_hash',
#        'attributed', 'implicit', 'device_countrycode', 'device_brand',
#        'device_model', 'session_user_agent', 'user_agent', 'event_uuid',
#        'kind', 'wifi', 'trans_id', 'ip_address', 'device_language'],
#       dtype='object')

# %%
installs.isnull().any()
# Out:
# created               False
# application_id        False
# ref_type              False
# ref_hash              False
# click_hash             True
# attributed            False
# implicit              False
# device_countrycode    False
# device_brand           True
# device_model           True
# session_user_agent     True
# user_agent             True
# event_uuid             True
# kind                   True
# wifi                   True
# trans_id               True
# ip_address            False
# device_language        True
# dtype: bool

# %%
installs['day_created'] = installs.created.str.slice(0, 10)
installs
# Out:
#                       created  application_id             ref_type  \
# 0     2019-03-13 01:43:33.445               0  1891515180541284343
# 1     2019-03-13 04:58:35.078               0  1891515180541284343
# 2     2019-03-13 04:20:57.666               0  1891515180541284343
# 3     2019-03-13 04:20:57.698               0  1891515180541284343
# 4     2019-03-10 22:24:56.684               0  1891515180541284343
# 5     2019-03-10 22:24:57.545               0  1891515180541284343
# 6     2019-03-11 03:47:22.802               0  1891515180541284343
# 7     2019-03-11 21:21:05.986               0  1891515180541284343
# 8     2019-03-11 21:21:05.855               0  1891515180541284343
# 9     2019-03-13 08:29:31.875               2  1891515180541284343
# 10    2019-03-13 04:30:00.812               2  1891515180541284343
# 11    2019-03-13 00:26:32.561               2  1891515180541284343
# 12    2019-03-13 11:36:30.025               2  1891515180541284343
# ...

# %%
#Se crea una columna que sólo contenga los días de creación y se la castea a datetime
installs['day_created'] = pd.to_datetime(installs.day_created)

# %%
#Se establece el rango temporal de la muestra
installs.created.max()
# Out:
# '2019-03-13 23:54:00.526'

# %%
installs.created.min()
# Out:
# '2019-03-05 00:00:38.219'

# %%
installs.day_created.max() - installs.day_created.min()
# Out:
# Timedelta('8 days 00:00:00')

# %%
installs.day_created.value_counts()
# Out:
# 2019-03-12    472
# 2019-03-13    423
# 2019-03-07    393
# 2019-03-11    377
# 2019-03-09    368
# 2019-03-08    366
# 2019-03-10    351
# 2019-03-05    337
# 2019-03-06    325
# Name: day_created, dtype: int64

# %%
installs.day_created.dt.weekday_name.value_counts()
# Out:
# Tuesday      809
# Wednesday    748
# Thursday     393
# Monday       377
# Saturday     368
# Friday       366
# Sunday       351
# Name: day_created, dtype: int64

# %%
plt.figure(figsize=(20, 6))
plt.hist(installs['created'], bins = 200, color = '#000000', alpha = 0.8)

plt.tick_params(top = False, bottom = True, left = False, right = False, labelleft = True, labelbottom = True)

for spine in plt.gca().spines.values():
    spine.set_visible(False)

plt.xticks(ticks = [pd.to_datetime('2019-03-05 12:00:00'), pd.to_datetime('2019-03-06 12:00:00'), pd.to_datetime('2019-03-07 12:00:00'), 
                    pd.to_datetime('2019-03-08 12:00:00'), pd.to_datetime('2019-03-09 12:00:00'), pd.to_datetime('2019-03-10 12:00:00'),
                   pd.to_datetime('2019-03-11 12:00:00'), pd.to_datetime('2019-03-12 12:00:00'), pd.to_datetime('2019-03-13 12:00:00')],
           labels = ['2019-03-05', '2019-03-06', '2019-03-07', '2019-03-08','2019-03-09', '2019-03-10', '2019-03-11', '2019-03-12', '2019-03-13'], 
           fontsize = 'large')
plt.ylabel('Cantidad de instalaciones', labelpad = 20, fontsize = 'x-large')
plt.title('Cantidad de instalaciones a lo largo del tiempo', fontsize = 'xx-large', pad = 20)


plt.show()

# %%
#Se visualiza la distribución de instalaciones por día 
installs_per_day = installs.day_created.value_counts().plot()
installs_per_day.set_title('Instalaciones por día')
installs_per_day.set_xlabel('Días')
installs_per_day.set_ylabel('Cantidad de instalaciones')
# Out:
# Text(0, 0.5, 'Cantidad de instalaciones')

# %%
#Se castea created a dateTime
installs['created'] = pd.to_datetime(installs.created)

# %%
#Se testea que efectivamente el día tenga 24 horas
installs.created.dt.hour.value_counts().count()
# Out:
# 24

# %%
installs.created.dt.hour.value_counts()
# Out:
# 17    233
# 22    229
# 15    220
# 23    212
# 19    211
# 14    201
# 21    198
# 0     198
# 1     191
# 20    188
# 16    186
# 2     174
# 18    170
# 13    169
# 12    130
# 11    116
# 3     115
# 4      76
# 10     63
# 5      38
# 8      28
# 9      27
# 7      21
# 6      18
# Name: created, dtype: int64

# %%
#Se grafica la distribución de instalaciones por hora
installs_per_hour = installs.created.dt.hour.value_counts().sort_index().plot()
installs_per_hour.set_title('Instalaciones por hora del día')
installs_per_hour.set_xlabel('Hora del día')
installs_per_hour.set_ylabel('Cantidad de instalaciones')
# Out:
# Text(0, 0.5, 'Cantidad de instalaciones')

# %%
installs.application_id.value_counts().count()
# Out:
# 31

# %%
installs.application_id.value_counts()
# Out:
# 7     947
# 9     731
# 10    389
# 16    362
# 8     328
# 2     174
# 29     97
# 20     95
# 6      35
# 1      34
# 26     28
# 34     28
# 15     20
# 0      18
# 3      17
# 28     17
# 12     15
# 18     14
# 24     13
# 17     13
# 14     13
# 21      7
# 5       3
# 13      3
# 33      2
# 30      2
# 19      2
# 32      2
# 36      1
# 4       1
# 23      1
# Name: application_id, dtype: int64

# %%
#Se gráfica cuáles fueron las aplicaciones más instaladas
application_id = installs.application_id.value_counts()
application_id_plot = application_id.plot.bar()
bar_application_ids = application_id_plot.set_title('Apliaciones más instaladas')
bar_application_ids = application_id_plot.set_xlabel('Id de la aplicación')
bar_application_ids = application_id_plot.set_ylabel('Cantidad de instalaciones')

# %%
top_5_installs = installs['application_id'].value_counts().sort_values(ascending = False).head(5)
top_5_installs
# Out:
# 7     947
# 9     731
# 10    389
# 16    362
# 8     328
# Name: application_id, dtype: int64

# %%
top_5_installs.sum()/len(installs['application_id']) * 100
# Out:
# 80.80304806565064

# %%
installs.ref_hash.value_counts()
# Out:
# 5208834946313176321    4
# 3272750442824629569    4
# 1999001885916451618    3
# 2457547163021424058    3
# 2515049144505739996    3
# 5376622639905210608    3
# 470581161921490835     3
# 2807966731127456435    3
# 394181128078904930     3
# 1332624341050561368    3
# 8209340170282049305    3
# 1826618012885478111    3
# 6207088909238189318    3
# 4603142710878547974    3
# 4587898421740190562    3
# 3429460795301152906    3
# 1838099903940931904    3
# 808602801225309575     3
# 2756309363004630634    3
# 5716316704073038128    3
# 1951826604052927528    3
# 5707101515634134793    3
# 3293250764324184935    3
# 6697381140026413622    2
# 1051816244049516468    2
# 2429923283539157643    2
# 8378288095655268347    2
# 4049391409413329307    2
# 1162390149017457197    2
# 8956666120381022264    2
#                       ..
# 432026705480919604     1
# 868940215859934734     1
# 4424921869962083331    1
# 667593224187123722     1
# 826262859425189535     1
# 3807326297196549242    1
# ...

# %%
installs.device_countrycode.value_counts()
# Out:
# 6333597102633388268    1820
# 2970470518450881158    1592
# Name: device_countrycode, dtype: int64

# %%
#Se grafica la distribución de instalaciones según el código del país (Faltaría agregarle el porcentaje)
labels = '6333597102633388268', '2970470518450881158'
colors = 'black', 'gray'
plt.pie(installs.device_countrycode.value_counts(), labels=labels, colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x1199b72e8>,
# ...
#  [Text(-0.11524996071619992, 1.0939458151823218, '6333597102633388268'),
#   Text(0.11524996071619956, -1.0939458151823218, '2970470518450881158')])

# %%
installs.device_brand.value_counts().count()
# Out:
# 27

# %%
installs.device_brand.value_counts()
# Out:
# 3.083059e+17    472
# 2.208835e+18    185
# 2.523246e+18    116
# 5.951325e+18     72
# 2.987569e+18     40
# 3.812621e+18     37
# 5.137992e+17     34
# 6.538562e+18     26
# 3.228516e+18      9
# 1.083369e+18      9
# 4.371308e+18      7
# 3.093166e+18      5
# 2.262848e+18      5
# 4.994101e+18      4
# 3.849490e+18      4
# 8.285870e+18      3
# 3.742387e+18      3
# 5.645692e+18      3
# 8.230045e+17      3
# 6.111647e+18      3
# 9.169527e+18      1
# 5.588755e+18      1
# 3.172231e+18      1
# 5.189983e+18      1
# 3.624089e+18      1
# 7.855186e+18      1
# 2.748831e+18      1
# Name: device_brand, dtype: int64

# %%
#Se establece la el número de instalaciones por marca del dispositivo
device_brands = installs.device_brand.value_counts()
device_brands_plot = device_brands.plot.bar()
device_brands_plot.set_title('Device Brands')
# Out:
# Text(0.5, 1.0, 'Device Brands')

# %%
installs.ip_address.value_counts().count()
# Out:
# 2717

# %%
installs.ip_address.value_counts()
# Out:
# 1992632945768888579    33
# 2403839579048525602    26
# 2394721645995561079    17
# 589886713227299026     16
# 8262991154202232888    14
# 8010533080341024188    13
# 8531002764348621869    12
# 7726314782926052608    12
# 7481987231813232849    11
# 2441645233986204328    11
# 2706357072127963511     9
# 3162368506662488065     9
# 6586849487961128061     7
# 7052859104363282878     7
# 9040150555093642379     7
# 627974920620404284      7
# 4895833194809562361     7
# 4371364616797404439     6
# 3222899837426106171     5
# 1037699812701179191     5
# 5437394128393850342     5
# 739514463662096135      5
# 6324037615828123965     5
# 8235954648733428120     5
# 7950883564880561905     5
# 3927367081536317814     5
# 7174799503430545910     4
# 2988221197536288219     4
# 6452955265823183819     4
# 1933486918445844180     4
#                        ..
# 1488715796382824376     1
# 8582476476054892626     1
# 7766233397987027039     1
# 2978724023808640249     1
# ...

# %%
#Se grafica la distribucín de las 3 apps más instaladas
biggest_ip_address_bins = [1, 2, 3, 4]
plt.hist(installs.ip_address.value_counts().tolist(), biggest_ip_address_bins, histtype='bar', rwidth=0.8)
# Out:
# (array([2310.,  326.,   55.]),
#  array([1, 2, 3, 4]),
#  <a list of 3 Patch objects>)

# %%
all_ip_addresses_bins = [5, 10, 15, 20, 25, 30, 35]
plt.hist(installs.ip_address.value_counts().tolist(), all_ip_addresses_bins, histtype='bar', rwidth=0.8)
# Out:
# (array([16.,  6.,  2.,  0.,  1.,  1.]),
#  array([ 5, 10, 15, 20, 25, 30, 35]),
#  <a list of 6 Patch objects>)

# %%
installs.implicit.value_counts()
# Out:
# False    2547
# True      865
# Name: implicit, dtype: int64

# %%
porcentage_implicit = installs['implicit'].value_counts(normalize=True) * 100
porcentage_implicit
# Out:
# False    74.6483
# True     25.3517
# Name: implicit, dtype: float64

# %%
#Se establece la distribucón de instalaciones implicitas y no implicitas (Falta agregar porcentajes)
labels = 'not implicit', 'implicit'
colors = 'blue', 'gray'
plt.pie(installs.implicit.value_counts(), labels=labels, colors=colors, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x11fbee978>,
# ...
#  [Text(-0.7691761350749687, 0.7863638300628618, 'not implicit'),
#   Text(0.7691762086996605, -0.7863637580473913, 'implicit')],
#  [Text(-0.4195506191318011, 0.4289257254888337, '74.6%'),
#   Text(0.4195506592907239, -0.42892568620766797, '25.4%')])

# %%
#Se ve la distribucón de los implicit por día
implicit_by_day = installs.groupby(['day_created', 'implicit']).size()
implicit_by_day
# Out:
# day_created  implicit
# 2019-03-05   False       265
#              True         72
# 2019-03-06   False       244
#              True         81
# 2019-03-07   False       274
#              True        119
# 2019-03-08   False       272
#              True         94
# 2019-03-09   False       280
#              True         88
# 2019-03-10   False       263
#              True         88
# 2019-03-11   False       280
#              True         97
# 2019-03-12   False       349
#              True        123
# 2019-03-13   False       320
#              True        103
# dtype: int64

# %%
implicit_by_day_DF = pd.DataFrame(implicit_by_day)
implicit_by_day_DF
# Out:
#                         0
# day_created implicit
# 2019-03-05  False     265
#             True       72
# 2019-03-06  False     244
#             True       81
# 2019-03-07  False     274
#             True      119
# 2019-03-08  False     272
#             True       94
# 2019-03-09  False     280
#             True       88
# 2019-03-10  False     263
#             True       88
# 2019-03-11  False     280
#             True       97
# 2019-03-12  False     349
#             True      123
# 2019-03-13  False     320
#             True      103

# %%
implicit_by_day_plot = implicit_by_day.plot.bar()
implicit_by_day_plot.set_title('Comparación de instalaciones por día según si es atribuida a Jampp')
implicit_by_day_plot.set_xlabel('Días')
implicit_by_day_plot.set_ylabel('Cantidad de instalaciones')
# Out:
# Text(0, 0.5, 'Cantidad de instalaciones')

# %%
implicit_by_day
# Out:
# implicit  application_id
# False     0                   9
#           1                  34
#           2                 135
#           3                  17
#           4                   1
#           6                  23
#           7                 775
#           8                 226
#           9                 535
#           10                247
#           12                  7
#           13                  3
#           14                 13
#           16                269
#           17                  7
#           18                 14
#           19                  2
#           20                 69
#           21                  4
#           23                  1
#           24                  8
#           26                 28
#           28                 17
#           29                 71
#           30                  1
#           32                  2
#           33                  1
#           34                 27
# ...

# %%
implicit_by_day

# %%
installs.kind.value_counts()
# Out:
# af_app_opened                 428
# app_open                      212
# EVENT_Homepage                 70
# open                           36
# EVENT_OPEN_APP                 33
# Open                           22
# login_success                  17
# account_summary_first_step     13
# EVENT_LISTINGVIEW_FLIGHT        6
# EVENT_HOMEPAGE                  6
# deeplink                        5
# reattribution                   4
# payment method add              3
# registration                    3
# journey first drop off          2
# af_list_view                    1
# journey drop off                1
# install                         1
# journey reserved                1
# EVENT_PROMO                     1
# Name: kind, dtype: int64

# %%
#Se muestra la recurrencia de los eventos ordenados de mayor a menor
kinds = installs.kind.value_counts()
kinds_plot = kinds.plot.bar()
kinds_plot.set_title('Kinds')
# Out:
# Text(0.5, 1.0, 'Kinds')

# %%
#Se ve la distribución de los lenguajes de los device (Faltaría graficar)
installs.device_language.value_counts()
# Out:
# 3.301378e+18    1484
# 9.028383e+18     714
# 4.621024e+18     632
# 6.977049e+18     238
# 4.077062e+17      70
# 1.526421e+18      56
# 4.060930e+18      48
# 2.822843e+17      39
# 6.035180e+18      24
# 1.193279e+18      21
# 6.535228e+18      10
# 1.101539e+17       9
# 3.177265e+18       5
# 3.695787e+17       5
# 3.095856e+18       4
# 6.569908e+18       2
# 5.846217e+18       2
# 7.774316e+18       2
# 4.594650e+18       2
# 6.782349e+18       1
# 5.061642e+18       1
# 1.686906e+18       1
# 5.794427e+17       1
# 2.488366e+18       1
# 3.544544e+18       1
# 3.074904e+18       1
# 2.061937e+18       1
# 4.073835e+18       1
# 6.846873e+18       1
# 7.045130e+18       1
# Name: device_language, dtype: int64

# %%
#Distribución de instalaciones por día según el aplication id
apps_instaled_per_day = installs.groupby(['day_created','application_id']).size()
apps_instaled_per_day
# Out:
# day_created  application_id
# 2019-03-05   0                   2
#              1                   5
#              2                  13
#              3                   1
#              4                   1
#              5                   1
#              6                   6
#              7                 114
#              8                  35
#              9                  60
#              10                 31
#              12                  7
#              14                  2
#              16                 22
#              17                  1
#              18                  1
#              19                  1
#              20                  8
#              24                  1
#              26                  3
#              28                  1
#              29                 15
#              32                  1
#              33                  2
#              34                  3
# 2019-03-06   0                   3
# ...

# %%
apps_instaled_per_day_2019_03_05 = apps_instaled_per_day['2019-03-05']
apps_instaled_per_day_2019_03_05_plot = apps_instaled_per_day_2019_03_05.plot.bar()
apps_instaled_per_day_2019_03_05_plot.set_title('Número de instalaciones por aplicación: 2019-03-05')
apps_instaled_per_day_2019_03_05_plot.set_xlabel('Id de la aplicación')
apps_instaled_per_day_2019_03_05_plot = apps_instaled_per_day_2019_03_05_plot.set_ylabel('Cantidad de instalaciones')

# %%
apps_instaled_per_day['2019-03-06']
# Out:
# application_id
# 0       3
# 1       1
# 2       5
# 3       2
# 6       2
# 7     102
# 8      32
# 9      82
# 10     22
# 12      1
# 15      2
# 16     32
# 17      2
# 18      1
# 20     10
# 23      1
# 24      2
# 26      3
# 28      4
# 29     13
# 34      3
# dtype: int64

# %%
apps_instaled_per_day_2019_03_06= apps_instaled_per_day['2019-03-06']
apps_instaled_per_day_2019_03_06_plot = apps_instaled_per_day_2019_03_06.plot.bar()
apps_instaled_per_day_2019_03_06_plot.set_title('Número de instalaciones por aplicación: 2019-03-06')
apps_instaled_per_day_2019_03_06_plot.set_xlabel('Id de la aplicación')
apps_instaled_per_day_2019_03_06_plot.set_ylabel('Cantidad de instalaciones')
# Out:
# Text(0, 0.5, 'Cantidad de instalaciones')

# %%
apps_instaled_per_day['2019-03-07']
# Out:
# application_id
# 0       3
# 1       2
# 2      14
# 3       2
# 5       1
# 6       4
# 7     122
# 8      41
# 9     100
# 10     27
# 12      1
# 13      1
# 14      2
# 15      5
# 16     41
# 19      1
# 20      7
# 26      1
# 28      2
# 29      6
# 32      1
# 34      8
# 36      1
# dtype: int64

# %%
apps_instaled_per_day_2019_03_07= apps_instaled_per_day['2019-03-07']
apps_instaled_per_day_2019_03_07_plot = apps_instaled_per_day_2019_03_07.plot.bar()
apps_instaled_per_day_2019_03_07_plot.set_title('Número de instalaciones por aplicación: 2019-03-07')
apps_instaled_per_day_2019_03_07_plot.set_xlabel('Id de la aplicación')
apps_instaled_per_day_2019_03_07_plot.set_ylabel('Cantidad de instalaciones')
# Out:
# Text(0, 0.5, 'Cantidad de instalaciones')

# %%
apps_instaled_per_day['2019-03-08']
# Out:
# application_id
# 0       1
# 1       3
# 2      16
# 3       2
# 7     108
# 8      34
# 9      85
# 10     32
# 12      1
# 14      2
# 15      3
# 16     41
# 17      2
# 18      8
# 20      9
# 24      1
# 26      4
# 28      2
# 29      7
# 34      5
# dtype: int64

# %%
apps_instaled_per_day_2019_03_08= apps_instaled_per_day['2019-03-08']
apps_instaled_per_day_2019_03_08_plot = apps_instaled_per_day_2019_03_08.plot.bar()
apps_instaled_per_day_2019_03_08_plot.set_title('Número de instalaciones por aplicación: 2019-03-08')
apps_instaled_per_day_2019_03_08_plot.set_xlabel('Id de la aplicación')
apps_instaled_per_day_2019_03_08_plot.set_ylabel('Cantidad de instalaciones')
# Out:
# Text(0, 0.5, 'Cantidad de instalaciones')

# %%
apps_instaled_per_day['2019-03-09']
# Out:
# application_id
# 1      7
# 2     13
# 3      5
# 6      5
# 7     97
# 8     42
# 9     53
# 10    49
# 14     2
# 15     5
# 16    40
# 17     2
# 18     2
# 20    12
# 21     4
# 24     3
# 26     5
# 28     4
# 29    14
# 30     2
# 34     2
# dtype: int64

# %%
apps_instaled_per_day_2019_03_09= apps_instaled_per_day['2019-03-09']
apps_instaled_per_day_2019_03_09_plot = apps_instaled_per_day_2019_03_09.plot.bar()
apps_instaled_per_day_2019_03_09_plot.set_title('Número de instalaciones por aplicación: 2019-03-09')
apps_instaled_per_day_2019_03_09_plot.set_xlabel('Id de la aplicación')
apps_instaled_per_day_2019_03_09_plot.set_ylabel('Cantidad de instalaciones')
# Out:
# Text(0, 0.5, 'Cantidad de instalaciones')

# %%
apps_instaled_per_day['2019-03-10']
# Out:
# application_id
# 0      2
# 1      3
# 2     32
# 3      2
# 5      1
# 6      6
# 7     90
# 8     44
# 9     54
# 10    46
# 13     1
# 14     1
# 15     1
# 16    28
# 17     2
# 18     1
# 20    11
# 24     1
# 26     8
# 28     1
# 29    14
# 34     2
# dtype: int64

# %%
apps_instaled_per_day_2019_03_10= apps_instaled_per_day['2019-03-10']
apps_instaled_per_day_2019_03_10_plots = apps_instaled_per_day_2019_03_10.plot.bar()
apps_instaled_per_day_2019_03_10_plots.set_title('Número de instalaciones por aplicación: 2019-03-10')
apps_instaled_per_day_2019_03_10_plots.set_xlabel('Id de la aplicación')
apps_instaled_per_day_2019_03_10_plots.set_ylabel('Cantidad de instalaciones')
# Out:
# Text(0, 0.5, 'Cantidad de instalaciones')

# %%
apps_instaled_per_day['2019-03-11']
# Out:
# application_id
# 0      3
# 1      5
# 2     24
# 3      1
# 6      6
# 7     97
# 8     27
# 9     74
# 10    53
# 12     3
# 14     3
# 15     1
# 16    50
# 17     2
# 20     6
# 21     2
# 24     2
# 26     3
# 28     3
# 29    11
# 34     1
# dtype: int64

# %%
apps_instaled_per_day_2019_03_11= apps_instaled_per_day['2019-03-11']
apps_instaled_per_day_2019_03_11_plot = apps_instaled_per_day_2019_03_11.plot.bar()
apps_instaled_per_day_2019_03_11_plot.set_title('Número de instalaciones por aplicación: 2019-03-11')
apps_instaled_per_day_2019_03_11_plot.set_xlabel('Id de la aplicación')
apps_instaled_per_day_2019_03_11_plot.set_ylabel('Cantidad de instalaciones')
# Out:
# Text(0, 0.5, 'Cantidad de instalaciones')

# %%
apps_instaled_per_day['2019-03-12']
# Out:
# application_id
# 1       5
# 2      40
# 6       3
# 7     108
# 8      38
# 9     115
# 10     68
# 12      1
# 14      1
# 15      3
# 16     63
# 17      1
# 18      1
# 20     15
# 24      2
# 29      6
# 34      2
# dtype: int64

# %%
apps_instaled_per_day_2019_03_12= apps_instaled_per_day['2019-03-12']
apps_instaled_per_day_2019_03_12_plot = apps_instaled_per_day_2019_03_12.plot.bar()
apps_instaled_per_day_2019_03_12_plot.set_title('Número de instalaciones por aplicación: 2019-03-12')
apps_instaled_per_day_2019_03_12_plot.set_xlabel('Id de la aplicación')
apps_instaled_per_day_2019_03_12_plot.set_ylabel('Cantidad de instalaciones')
# Out:
# Text(0, 0.5, 'Cantidad de instalaciones')

# %%
apps_instaled_per_day['2019-03-13']
# Out:
# application_id
# 0       4
# 1       3
# 2      17
# 3       2
# 6       3
# 7     109
# 8      35
# 9     108
# 10     61
# 12      1
# 13      1
# 16     45
# 17      1
# 20     17
# 21      1
# 24      1
# 26      1
# 29     11
# 34      2
# dtype: int64

# %%
apps_instaled_per_day_2019_03_13= apps_instaled_per_day['2019-03-13']
apps_instaled_per_day_2019_03_13_plot = apps_instaled_per_day_2019_03_13.plot.bar()
apps_instaled_per_day_2019_03_13_plot.set_title('Número de instalaciones por aplicación: 2019-03-13')
apps_instaled_per_day_2019_03_13_plot.set_xlabel('Id de la aplicación')
apps_instaled_per_day_2019_03_13_plot.set_ylabel('Cantidad de instalaciones')
# Out:
# Text(0, 0.5, 'Cantidad de instalaciones')

# %%
installs.application_id.value_counts()
# Out:
# 7     947
# 9     731
# 10    389
# 16    362
# 8     328
# 2     174
# 29     97
# 20     95
# 6      35
# 1      34
# 26     28
# 34     28
# 15     20
# 0      18
# 3      17
# 28     17
# 12     15
# 18     14
# 24     13
# 17     13
# 14     13
# 21      7
# 5       3
# 13      3
# 33      2
# 30      2
# 19      2
# 32      2
# 36      1
# 4       1
# 23      1
# Name: application_id, dtype: int64

# %%
#se ven los event_uuid (Es completamente uniforme). No sé si aporta demasiado valor al caso
installs.event_uuid.value_counts()
# Out:
# 77de6df9-e573-4f81-8bf8-25831ead7535    1
# 46a674c0-3025-4ec6-928d-50cc8cc6dc4c    1
# ab9ab736-b438-44c2-8054-cc1f21f8b720    1
# 8573dc0e-817e-4c1f-a989-fa0d0ef75417    1
# f80661c9-cc7f-4ee0-a28e-23d1946901ec    1
# a0795ce6-a85a-48a2-9d45-9bcabb589ac7    1
# 6837bfef-e84a-4b60-85d1-40d03270766f    1
# 24771191-c52d-4451-9e9e-1b75f475d751    1
# d8efd285-22db-46cb-9774-f567c8ea17ae    1
# bcf4a04a-8d51-41c2-9bbd-4e3c556b61bc    1
# 5325fb17-a9e7-40bd-aae1-2bffcdb88fcf    1
# 2f202df6-fabb-4ffa-9a21-39a10feeefca    1
# be00ec34-7634-480c-9a49-fcdf6a5bf6c2    1
# 7a26f64d-926b-4c72-9417-bc0355cbf9a9    1
# 08e954a4-d5a5-4720-b826-07be6e4eccc3    1
# 35324de3-4cd2-48c4-889c-ba4fe3375944    1
# 1e161901-3af0-4156-8b41-16be643ba924    1
# 17fc487c-3668-445a-b230-b6d67f4467d2    1
# 2a562a66-4bfd-49b3-a9d4-0b6e1ed34ac4    1
# 4501d1ad-b8e2-44f9-a7f2-62a16ad4528f    1
# ea0a817a-dbd8-425e-a20c-3ad171236dda    1
# 1f952b23-834f-46dd-ad8c-2e3d12ecba51    1
# ...

# %%
installs.session_user_agent.value_counts()
# Out:
# http-kit/2.0                                                                                                                                                                                                                                                                  1729
# adjust.com                                                                                                                                                                                                                                                                    1592
# HasOffers Mobile AppTracking v1.0                                                                                                                                                                                                                                               22
# ...

# %%
# Se establece una comparación de los distintos session_user_agent
sessions_user_agent = installs.session_user_agent.value_counts()
sessions_user_agentPlot = sessions_user_agent.plot.bar()
sessions_user_agentPlot.set_title('Session User Agent')
# Out:
# Text(0.5, 1.0, 'Session User Agent')

# %%
wifi= installs.wifi.value_counts()
wifi
# Out:
# True     1377
# False     352
# Name: wifi, dtype: int64

# %%
#Comparación de la cantidad de instalaciones con Wifi y sin wifi
wifi = wifi.plot.bar()
wifi.set_title('Wifi')
# Out:
# Text(0.5, 1.0, 'Wifi')

# %%
installs.trans_id.value_counts()
# Out:
# {hash}                                  3
# 44aeb6df-8db4-4b3f-ac67-0a802d479c86    1
# 89bda305-bff1-4c22-ae23-1a237eac0002    1
# 22380348598                             1
# Name: trans_id, dtype: int64
